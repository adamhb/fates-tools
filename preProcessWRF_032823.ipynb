# %% [markdown]
# # Pre-process WRF DATM

# %%
import os

import xarray as xr
import functools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import glob
import re

# %matplotlib inline

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### User-defined parameters

# %%
#1.
#path to regional wrf data that you want to subset from
#wrf_data = '/glade/scratch/adamhb/met_data/wrf_9km_1982_2020/'

# Reanalysis
#wrf_data = '/glade/work/xiugao/fates-input/ca-wrf-grassland/CLM1PT_data'

# Projections
wrf_data ='/glade/work/xiugao/fates-input/ca-wrf-grassland/ec-earth3-ssp370-2015-2099'

#2.
#output path where you want the subsetted, pre-processed data to go
output_path = '/glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data/'

#3.
#Coordinates of site where you want to subset data

#CZ2: 37.0311,-119.256599
#STAN: 38.177648,-119.978692

target_wrf_lat = 37.0311
target_wrf_lon = -119.256599

# %% [markdown]
# ### User should not need to change anything after this point

# %% [markdown]
# ### Constants

# %%
# Molar mass of water vapour [kg/mol]
mm_h2o  = 0.01801505
# Molar mass of dry air [kg/mol]
mm_dry  = 0.02897
# Molar mass ratio
eps_mol = mm_h2o / mm_dry
# Saturation vapour pressure at 273.15K [Pa]
esat_0C = 611.65685464
frac_2_pc = 100
degC_2_K  = 273.15

site_refhgt=2

# Convert the user-defined target lon to be non-negative in the western hemisphere.
# This is to match clm format
target_lat = target_wrf_lat

if target_wrf_lon < 0:
    target_lon = target_wrf_lon + 360

# %% [markdown]
# ### Get WRF LAT and LON indices at the closest WRF point to the target site

# %%
def dist_func(a,b):
    return math.sqrt(a**2 + b**2)

def getDiff(d,var,target,r,c):
    return abs(d[var][r,c].values - target)

def getClosestWRFPoint(xds,lat_target,lon_target):

    output = {'lat':[],'lon':[],'dist':[]}
    for r in range(xds.LATIXY.shape[0]):
        for c in range(xds.LATIXY.shape[1]):

            lon_diff = getDiff(xds,'LONGXY',lon_target,r,c)
            lat_diff = getDiff(xds,'LATIXY',lat_target,r,c)
            dist = dist_func(lon_diff, lat_diff)
            output['lat'].append(r)
            output['lon'].append(c)
            output['dist'].append(dist)
            
    output = pd.DataFrame(output)
    closest = output.loc[output.dist == output.dist.min()]
    lat_index = closest.lat.values
    lon_index = closest.lon.values
    return lat_index[0], lon_index[0]

def get_last_file_of_sim(sim_path):
    files = sorted(os.listdir(sim_path))
    full_files = [os.path.join(sim_path,f) for f in files]
    last_file = full_files[-1]
    print("last file:",last_file)
    return last_file

def return_sorted_wrf_files(directory_path):
    matching_files = []
    pattern = re.compile(r'\d{4}-\d{2}\.nc')

    for filename in os.listdir(directory_path):
        if pattern.match(filename):
            matching_files.append(os.path.join(directory_path, filename))

    return sorted(matching_files)


#Get lat and lon indices of WRF data at closest point to target location (i.e. the site)
ds_01 = xr.open_dataset(return_sorted_wrf_files(wrf_data)[-1],decode_times = False)
wrf_lat_index, wrf_lon_index = getClosestWRFPoint(ds_01,target_wrf_lat,target_wrf_lon)


print("Target Latitude (i.e. site latitude):",target_wrf_lat)
print("Latitude index of closest WRF point:",wrf_lat_index)
print("Latitude of closest WRF point:",ds_01.LATIXY.sel(lat = wrf_lat_index,lon = wrf_lon_index).values)

print("\n")

print("Target Longitude (i.e. site longitude):", target_wrf_lon)
print("Longitude index of closest WRF point:",wrf_lon_index)
print("Latitude of closest WRF point:", ds_01.LONGXY.sel(lat = wrf_lat_index,lon = wrf_lon_index).values)
# Out:
# Target Latitude (i.e. site latitude): 37.0311
# Latitude index of closest WRF point: 74
# Latitude of closest WRF point: 37.07170104980469
#
#
# Target Longitude (i.e. site longitude): -119.256599
# Longitude index of closest WRF point: 74
# Latitude of closest WRF point: -119.22645568847656

# %% [markdown]
# ### Functions to pre-process WRF data

# %%
def cast_all_vars_to_float32(xds):
    vars = list(xds.keys())
    for v in vars:
        float_32_var = xds[v].astype("float32")
        xds[v] = float_32_var
    return xds

def change_LATIXY_and_LONGXY(xds,lat,lon):
    LONGXY_attrs = xds.LONGXY.attrs
    LATIXY_attrs = xds.LATIXY.attrs
    new_LATIXY = xr.DataArray(data = np.array(lat,dtype = "float32").reshape(1,1),
                              dims = ['lat','lon'],
                              attrs = LATIXY_attrs)
    new_LONGXY = xr.DataArray(data = np.array(lon,dtype = "float32").reshape(1,1),
                              dims = ['lat','lon'],
                              attrs = LONGXY_attrs)
    
    xds['LATIXY'] = new_LATIXY
    xds['LONGXY'] = new_LONGXY
    return xds

def getRH_from_QBOT(QBOT,PSRF,TBOT):

    EBOT = PSRF * QBOT / (eps_mol + (1. - eps_mol) * QBOT)
    ESAT = esat_0C * math.exp( 17.67 * (TBOT - degC_2_K) / (TBOT - 29.65))
    RH   = frac_2_pc * EBOT / ESAT
    return RH

    
def put_RH_in_array(xds):
    QBOT_array = list(xds.QBOT.values)
    PSRF_array = list(xds.PSRF.values)
    TBOT_array = list(xds.TBOT.values)
    times = xds.time.values

    RH_array = np.zeros(len(QBOT_array))
    for i in range(len(QBOT_array)):
        RH_array[i] = getRH_from_QBOT(QBOT_array[i],PSRF_array[i],TBOT_array[i])

    return RH_array


def add_RH_to_data(xds):
    times = xds.time.values
    n = len(times)
    RH_array = put_RH_in_array(xds)

    RH_xda = xr.DataArray(
                 data = np.array(RH_array).reshape(n,1,1),
                 dims = ['time','lat','lon'],
                 coords = {"time": times},
                 attrs = {
                     'longname': 'relative humidity',
                     'units' : '%',
                     'mode' : 'time-dependent'
                     })
    xds['RH'] = RH_xda

def add_ZBOT_to_data(xds):
    times = xds.time.values
    n = len(xds.time.values)                    
    ZBOT_array = np.array([site_refhgt] * n).reshape(n,1,1) 
                        
    ZBOT_xda = xr.DataArray(
                 data = ZBOT_array.reshape(n,1,1),
                 dims = ['time','lat','lon'],
                 coords = {"time": times},
                 attrs = {
                     'longname': 'observation_height',
                     'units' : 'm',
                     'mode' : 'time-dependent'
                     })
    xds['ZBOT'] = ZBOT_xda

    
def add_EDGE_vars(xds):
    
    add = [0.5,-0.5,0.5,-0.5]
    var = ['LATIXY','LATIXY','LONGXY','LONGXY']
    for i,d in enumerate(['N','S','E','W']):
        edge_var_name = "EDGE" + d
        edge_value = xds[var[i]].values + add[i]
        edge_xar = xr.DataArray(
                     data = edge_value[0,:],
                     dims = ['scalar'],
                     attrs = {
                     'longname': 'edge of datm',
                     'units' : 'degrees',
                     'mode' : 'time-dependent'
                     })
        xds[edge_var_name] = edge_xar

            
def subset_single_file(file):
    ds = xr.open_dataset(file, decode_times = False)
    
    #subset
    point_data = ds.sel(lat = slice(wrf_lat_index,(wrf_lat_index+1)),
                        lon = slice(wrf_lon_index,(wrf_lon_index+1)))
    
    #get time attributes
    time_attrs = point_data.time.attrs
    
    #add variables
    add_ZBOT_to_data(point_data)
    add_RH_to_data(point_data)
        
    #reset lat and lon to be same as surf data
    point_data = change_LATIXY_and_LONGXY(cast_all_vars_to_float32(point_data),target_lat,target_lon)
    
    #add edge values
    add_EDGE_vars(point_data)
    
    #re-assign time attributes to data
    point_data.time.attrs = time_attrs
    
    #write output
    new_file_name = output_path + "/" + os.path.basename(file)
    point_data.to_netcdf(new_file_name, format = "NETCDF3_64BIT", mode = "w")
    ds.close()
    point_data.close()
    print("Finished",new_file_name)

# %% [markdown]
# ### Apply pre-processing functions to WRF domain files

# %%
#files = glob.glob(wrf_data + "/*1980*.nc")
files = return_sorted_wrf_files(wrf_data)

# %%
for f in sorted(files):
    subset_single_file(f)
# Out:
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2014-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2014-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2014-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2014-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2015-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2016-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2017-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2018-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2019-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2020-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2021-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2022-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2023-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2024-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2025-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2026-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2027-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2028-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2029-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2030-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2031-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2032-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2033-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2034-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2035-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2036-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2037-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2038-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2039-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2040-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2041-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2042-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2043-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2044-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2045-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2046-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2047-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2048-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2049-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2050-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2051-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2052-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2053-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2054-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2055-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2056-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2057-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2058-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2059-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2060-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2061-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2062-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2063-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2064-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2065-11.nc
# ...
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2083-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2083-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2083-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2083-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2083-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2084-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2085-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2086-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2087-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2088-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2089-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2090-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2091-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2092-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2093-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2094-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2095-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2096-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2097-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2098-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-08.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-09.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-10.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-11.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2099-12.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-01.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-02.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-03.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-04.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-05.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-06.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-07.nc
# Finished /glade/work/adamhb/input_data/CZ2_wrf_ssp370/CLM1PT_data//2100-08.nc
